# %%
POPULATION_SIZE = 500
GENERATIONS = 100
MAX_DEPTH = 10
MUTATION_RATE = 0.2
CROSSOVER_RATE = 0.8 
ELITISM_RATE = 0.20
TOURNAMENT_SIZE = 3   
SEED = 42

# %%
import numpy as np
import operator, math
from gp_tree import SymbolicRegression
import s326492 as fun
import numpy as np

if __name__ == "__main__":
    problem = np.load('../data/problem_2.npz')
    problem.keys()

    x = problem["x"]
    y = problem["y"]

    print("Number variables : ", x.shape[0], ", Number samples : ", x.shape[1])

    # Definizione delle variabili e operatori
    variables = [f"x{i}" for i in range(x.shape[0])]
    operators = [operator.add, operator.sub, operator.mul, operator.truediv, math.sin, math.cos, math.tan, math.log, math.sqrt]

    sr = SymbolicRegression(variables, operators, POPULATION_SIZE, GENERATIONS, MUTATION_RATE, CROSSOVER_RATE, ELITISM_RATE, TOURNAMENT_SIZE, MAX_DEPTH, SEED)

    best_formula = sr.fit(x, y)

    print("Best formula:", best_formula.long_name) 

#Problema 1
#Best MSE =  7.125940794232773e-34
#Formula = sin(x0)

#Problema 2 - 
#Best MSE = 9909848386207.594, Tree Depth = 32
#Formula = add(add(add(mul(sqrt(log(cos(log(mul(x2, x1))))), x0), sub(sub(sub(sub(sqrt(mul(mul(x0, add(mul(x2, x1), tan(x2))), sqrt(log(sqrt(truediv(x2, 10.543510297651773)))))), sub(10.924171372825635, log(mul(mul(x0, add(sqrt(truediv(add(x0x2, truediv(1.552613023714905, x2)), truediv(sin(x0), sqrt(sqrt(truediv(-0.7557112491004349, x0)))))), truediv(-47.45540488754337, sqrt(sqrt(mul(sub(mul(x0, add(log(log(mul(x0, 9.063692540724073))), tan(x2))), sqrt(log(sub(sub(sqrt(truediv(-0.7557112491004349, x0)), truediv(-0.7557112491004349, x0)), log(mul(mul(x0, mul(x2, x1)), sqrt(log(sqrt(truediv(cos(log(mul(x2, x1))), 10.543510297651773)))))))))), -0.05123147968650968)))))), sqrt(sqrt(truediv(-0.7557112491004349, x0))))))), log(mul(mul(x0, add(log(log(mul(x2, x1))), tan(x2))), sqrt(log(sqrt(add(cos(log(mul(x2, mul(truediv(-47.45540488754337, sqrt(sqrt(x0))), x0)))), sub(10.924171372825635, log(cos(log(mul(x2, x1)))))))))))), -11.679882621926069), log(mul(mul(x0, add(log(log(mul(truediv(-0.7557112491004349, x0), x1))), tan(x2))), sqrt(log(cos(log(mul(x2, x1))))))))), sub(sub(sub(sub(sqrt(mul(mul(x0, add(log(log(mul(x0, 0.5770494313955103))), tan(x2))), sqrt(log(sqrt(truediv(x2, 10.543510297651773)))))), sub(10.924171372825635, log(mul(mul(x0, add(sqrt(truediv(add(x0x2, truediv(1.552613023714905, x2)), truediv(sin(x0), sqrt(sqrt(mul(x0, mul(x2, x1))))))), truediv(-47.45540488754337, truediv(x1, x0)))), sqrt(sqrt(truediv(-0.7557112491004349, x0))))))), log(mul(mul(x0, add(log(log(mul(x2, x1))), tan(cos(log(mul(x2, x1)))))), sqrt(log(sqrt(add(mul(sqrt(log(-0.7066229850527771)), cos(log(mul(x2, x1)))), sub(10.924171372825635, log(mul(mul(x0, add(log(log(-0.7106204308378148)), add(log(log(-47.45540488754337)), truediv(-47.45540488754337, sqrt(sqrt(x0)))))), sqrt(sqrt(truediv(sqrt(log(sqrt(add(cos(log(mul(x2, mul(truediv(-47.45540488754337, sqrt(sqrt(x0))), x0)))), sub(10.924171372825635, log(cos(log(mul(x2, x1))))))))), x0))))))))))))), -11.679882621926069), log(mul(mul(x0, add(log(log(mul(truediv(-0.7557112491004349, x0), x1))), tan(x2))), sqrt(log(cos(log(mul(x2, x1))))))))), sub(sub(sub(sqrt(mul(mul(x0, add(-0.8211184404845606, tan(x2))), sqrt(log(sqrt(truediv(x2, 10.543510297651773)))))), sub(10.924171372825635, log(mul(mul(x0, add(sqrt(truediv(add(x0x2, truediv(1.552613023714905, x2)), truediv(sin(x0), sqrt(sqrt(truediv(-0.7557112491004349, x0)))))), truediv(-47.45540488754337, sqrt(sqrt(mul(sub(mul(x0, add(x1, tan(add(log(x0x2), -11.679882621926069)))), sqrt(log(sub(sub(sqrt(truediv(-0.7557112491004349, x0)), -11.679882621926069), log(mul(mul(x0, mul(x2, x1)), sqrt(log(sqrt(mul(x2, x1)))))))))), -0.05123147968650968)))))), sqrt(sqrt(truediv(-0.7557112491004349, x0))))))), log(mul(sub(sub(sub(sub(sqrt(mul(mul(x0, add(mul(x2, x1), tan(x2))), sqrt(log(sqrt(truediv(x2, 10.543510297651773)))))), sub(10.924171372825635, log(mul(mul(x0, add(sqrt(truediv(add(x0x2, truediv(1.552613023714905, x2)), truediv(sin(x0), sqrt(sqrt(truediv(-0.7557112491004349, x0)))))), truediv(-47.45540488754337, sqrt(sqrt(mul(sub(mul(x0, add(log(log(mul(x0, 9.063692540724073))), tan(x2))), sqrt(log(sub(sub(sqrt(truediv(-0.7557112491004349, x0)), truediv(-0.7557112491004349, x0)), log(mul(mul(x0, mul(x2, x1)), sqrt(log(sqrt(truediv(cos(log(mul(x2, x1))), 10.543510297651773)))))))))), -0.05123147968650968)))))), sqrt(sqrt(truediv(-0.7557112491004349, x0))))))), log(mul(mul(x0, add(log(log(mul(x2, x1))), tan(x2))), sqrt(log(sqrt(add(cos(log(mul(x2, x1))), sub(10.924171372825635, log(cos(log(mul(x2, x1)))))))))))), -11.679882621926069), log(mul(mul(x0, add(log(log(mul(truediv(-0.7557112491004349, x0), x1))), tan(x2))), sqrt(log(cos(log(mul(x2, x1)))))))), sqrt(log(sqrt(add(mul(sqrt(truediv(add(x0x2, truediv(1.552613023714905, x2)), truediv(sin(x0), sqrt(sqrt(truediv(-0.7557112491004349, x0)))))), cos(log(mul(x2, mul(x2, x1))))), sub(10.924171372825635, log(mul(mul(x0, add(log(log(-0.7106204308378148)), truediv(-47.45540488754337, sqrt(sqrt(x0))))), x2)))))))))), log(mul(mul(x0, add(log(log(cos(log(-0.7106204308378148)))), truediv(-47.45540488754337, sqrt(sqrt(x0))))), cos(log(mul(x2, x1)))))))


#Problema 3
#Best MSE = 0.600077793309
#Formula = sub(add(sub(mul(x0, x0), add(1.1418843909085017, x2)), sub(sin(mul(1.4708865048241961, sin(mul(1.4708865048241961, sqrt(truediv(add(0.22273292799471647, x2), sub(cos(add(sqrt(add(sqrt(add(sub(mul(x0, x0), x2), sub(5.585092387202902, x2))), 1.4708865048241961)), cos(cos(cos(sin(sqrt(x1))))))), 1.4708865048241961))))))), x2)), sub(mul(x1, mul(x1, x1)), add(sub(mul(x0, x0), 0.5543653734888427), sub(5.585092387202902, x2))))

#Problema 4 
#Best MSE = 0.095873275087
#Formula = add(sqrt(11.03857004111608), mul(7.246489470867109, cos(x1)))

#Problema 5
# Best MSE =  9.883570418267258e+44
#Formula = truediv(truediv(sub(4.763507446791947, mul(add(6.366218889989474, x0), mul(14.5621393076764, x1))), mul(add(11.350143908794207, add(0.5746784376176798, sqrt(-0.24854569754379913))), sqrt(mul(x1, cos(x0))))), sqrt(add(sub(mul(cos(x1), x1), x1), -8.401825820036258)))

#Problema 6
#Best MSE =  0.004311656386509286
#Formula = add(add(mul(sub(x1, x0), 0.6945167491855171), x1), truediv(mul(truediv(sub(x1, x0), 0.5316369921713702), -0.8887837131639956), truediv(sub(log(add(sub(x1, 6.2182907542118135), mul(x0, 0.6945167491855171))), truediv(truediv(log(add(sub(x1, mul(sub(sin(sin(sin(x0))), x1), 0.6945167491855171)), 1.4991471060669044)), add(sub(x1, 6.2182907542118135), add(truediv(sub(x1, x0), 9.56558657963237), x1))), 16.896222326564367)), log(truediv(truediv(mul(sub(x1, sub(x1, x0)), 0.6945167491855171), 6.2182907542118135), x0)))))

#Problema 7
#Best MSE =  256.63535635927843
#Formula = add(mul(mul(x0, add(tan(cos(sub(truediv(18.942587401015892, add(mul(mul(x0, 5.309087692328209), x1), add(truediv(x0, 0.6666078913314124), add(tan(cos(truediv(18.942587401015892, add(0.09330080325717367, add(tan(tan(cos(sub(x1, x0)))), cos(sub(x0, 0.7510055024396474))))))), sub(4.855519087488644, sin(tan(log(x0)))))))), 5.309087692328209))), add(mul(mul(x0, 5.309087692328209), x1), add(tan(cos(truediv(mul(mul(add(tan(cos(sub(truediv(18.942587401015892, add(mul(mul(x0, 5.309087692328209), x1), add(x1, cos(sub(add(sub(6.605917439028706, sub(6.890095078240755, x0)), truediv(truediv(mul(mul(x0, 5.309087692328209), x1), sqrt(mul(6.469925521136108, x1))), x0)), x0))))), 5.309087692328209))), add(mul(mul(x0, 5.309087692328209), x1), add(tan(cos(truediv(18.942587401015892, sqrt(mul(6.469925521136108, x1))))), sub(4.855519087488644, sin(tan(log(x0))))))), 5.309087692328209), x1), add(mul(mul(x0, 5.309087692328209), x1), add(0.09330080325717367, cos(sub(x0, sub(cos(x0), x1)))))))), sub(4.855519087488644, sin(tan(log(sub(x1, x0))))))))), x1), add(tan(tan(cos(sub(x1, x0)))), cos(sub(cos(x0), x1))))

#Problema 8
#Best MSE =  1194339.3546052114
#Formula = mul(add(mul(mul(11.262832907882053, x5), add(sin(sqrt(sqrt(mul(add(mul(5.257718390320081, sub(x5, -0.09553543323136982)), sqrt(add(mul(0.0030932378592536795, add(add(sqrt(x5), mul(mul(mul(mul(11.262832907882053, x5), add(sin(sqrt(sqrt(mul(add(-225.60053506465715, sqrt(add(mul(11.262832907882053, add(add(x3, mul(5.257718390320081, x5)), add(x3, mul(x5, x5)))), -225.60053506465715))), sqrt(x5))))), mul(11.262832907882053, sub(x5, sin(sqrt(x5)))))), x5), x5)), add(x3, mul(11.262832907882053, x5)))), -225.60053506465715))), sqrt(x5))))), add(sin(sqrt(sqrt(mul(add(mul(5.257718390320081, sub(x5, -0.09553543323136982)), sqrt(add(mul(0.0030932378592536795, add(add(sqrt(x5), mul(mul(add(sqrt(mul(5.257718390320081, sub(sqrt(x5), sin(sqrt(x5))))), add(x3, mul(11.262832907882053, add(mul(mul(11.262832907882053, x5), add(sin(sqrt(sqrt(mul(add(mul(mul(add(mul(mul(11.262832907882053, x5), add(sin(x3), mul(11.262832907882053, x5))), -225.60053506465715), mul(mul(sin(sqrt(sin(sqrt(sqrt(x5))))), -214.3377021567751), add(add(x3, mul(x5, mul(11.262832907882053, x5))), mul(11.262832907882053, x5)))), x5), sqrt(add(mul(0.0030932378592536795, add(add(x3, mul(5.257718390320081, sin(x3))), add(sub(mul(sqrt(x3), x5), x1), mul(11.262832907882053, x5)))), -225.60053506465715))), sin(sqrt(sqrt(mul(add(mul(mul(5.257718390320081, mul(mul(sin(sqrt(sin(sqrt(sqrt(x5))))), x5), add(mul(mul(5.257718390320081, mul(mul(sub(x5, sin(sqrt(add(x3, mul(-225.60053506465715, x5))))), x5), add(add(-0.9644984861459652, mul(11.262832907882053, x5)), mul(11.262832907882053, x5)))), -0.9644984861459652), sqrt(add(mul(0.0030932378592536795, add(add(x3, mul(5.257718390320081, x5)), add(x3, mul(11.262832907882053, add(-1.129596097084491, add(sin(tan(sin(x3))), x5)))))), -225.60053506465715))))), -0.9304851664500571), sqrt(add(mul(0.0030932378592536795, sin(tan(sin(x3)))), x5))), sqrt(x5))))))))), x5)), -225.60053506465715)))), x5), x5)), add(x3, mul(11.262832907882053, x5)))), -225.60053506465715))), sqrt(x5))))), mul(11.262832907882053, sub(x5, sin(sqrt(x5))))))), -225.60053506465715), x5)
# Out:
# Number variables :  3 , Number samples :  5000
# MSE =  29618320502086.266
